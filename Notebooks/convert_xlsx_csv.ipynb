# %%
import pandas as pd

# Lee el archivo Excel
df = pd.read_excel('../NODSV_database_galactic_all.xlsx')

# %%
df.columns.tolist()
# Out:
# ['No.',
#  'Star name',
#  'Galaxy',
#  'Constellation',
#  'Status',
#  'Suspected (Year)',
#  'Confirmed (Year)',
#  'SIMBAD',
#  'Gaia DR3',
#  '2MASS',
#  'WISE',
#  'IRAS',
#  'Pan-STARRS',
#  'SkyMapper',
#  'HIP',
#  'TYC',
#  'GSC2.4.2',
#  'SAO',
#  'WRAY',
#  'Hen',
#  'ESO',
#  'AAVSO',
#  'VSX',
#  'GCVS',
#  'BD',
#  'HD',
#  'Bidelman (1954)',
#  'Bidelman (1954) status',
#  'Gaposchkin (1957)',
#  'Gaposchkin (1957) status',
#  'Boyarchuk (1969)',
#  'Boyarchuk (1969) status',
#  'Allen (1984)',
#  'Allen (1984) status',
#  'Kenyon (1986)',
#  'Kenyon (1986) status',
#  'Vaidis (1988, 1991)',
#  'Vaidis (1988, 1991) status',
#  'Belzcyński et al. (2001)',
#  'Belzcyński et al. (2001) status',
#  'Akras et al. (2019)',
#  'Akras et al. (2019) status',
#  'Right ascension (°)',
#  'Right ascension (HH MM SS.s)',
#  'Declination (°)',
#  'Declination (DD MM SS.s)',
#  'Galactic longitude  (°)',
#  'Galactic latitude  (°)',
#  'Parallax (mas)',
#  'Distance (kpc)',
# ...

# %%
# Renombra solo las columnas deseadas
df = df.rename(columns={
    'Right ascension (°)': 'RA',
    'Declination (°)': 'DEC'
})

# %%
df.columns.tolist()
# Out:
# ['No.',
#  'Star name',
#  'Galaxy',
#  'Constellation',
#  'Status',
#  'Suspected (Year)',
#  'Confirmed (Year)',
#  'SIMBAD',
#  'Gaia DR3',
#  '2MASS',
#  'WISE',
#  'IRAS',
#  'Pan-STARRS',
#  'SkyMapper',
#  'HIP',
#  'TYC',
#  'GSC2.4.2',
#  'SAO',
#  'WRAY',
#  'Hen',
#  'ESO',
#  'AAVSO',
#  'VSX',
#  'GCVS',
#  'BD',
#  'HD',
#  'Bidelman (1954)',
#  'Bidelman (1954) status',
#  'Gaposchkin (1957)',
#  'Gaposchkin (1957) status',
#  'Boyarchuk (1969)',
#  'Boyarchuk (1969) status',
#  'Allen (1984)',
#  'Allen (1984) status',
#  'Kenyon (1986)',
#  'Kenyon (1986) status',
#  'Vaidis (1988, 1991)',
#  'Vaidis (1988, 1991) status',
#  'Belzcyński et al. (2001)',
#  'Belzcyński et al. (2001) status',
#  'Akras et al. (2019)',
#  'Akras et al. (2019) status',
#  'RA',
#  'Right ascension (HH MM SS.s)',
#  'DEC',
#  'Declination (DD MM SS.s)',
#  'Galactic longitude  (°)',
#  'Galactic latitude  (°)',
#  'Parallax (mas)',
#  'Distance (kpc)',
#  'Geometric distance (kpc)',
# ...

# %%
# Guarda el DataFrame como CSV
df.to_csv('../SySt_NODSV_database_galactic_all.csv', index=False)
